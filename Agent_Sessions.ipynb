# %% [markdown]
# <a href="https://colab.research.google.com/github/itssraj/ai-agents-using-ADK/blob/main/Agent_Sessions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this notebook,
#
# - ✅ What sessions are and how to use them in your agent
# - ✅ How to build *stateful* agents with sessions and events
# - ✅ How to persist sessions in a database
# - ✅ Context management practices such as context compaction
# - ✅ Best practices for sharing session State

# %% [markdown]
# ---
# ## ⚙️ Section 1: Setup
#
# ### 1.1: Install dependencies
#
#
# To install and use ADK in your own Python development environment outside of this course, you can do so by running:
#
# ```
# pip install google-adk
# ```

# %% [markdown]
# ### 1.2: Configure your Gemini API Key
#
# This notebook uses the [Gemini API](https://ai.google.dev/gemini-api/docs), which requires authentication.

# %%
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %% [markdown]
# ### 1.3: Import ADK components
#
# Now, import the specific components you'll need from the Agent Development Kit and the Generative AI library. This keeps your code organized and ensures we have access to the necessary building blocks.

# %%
from typing import Any, Dict

from google.adk.agents import Agent, LlmAgent
from google.adk.apps.app import App, EventsCompactionConfig
from google.adk.models.google_llm import Gemini
from google.adk.sessions import DatabaseSessionService
from google.adk.sessions import InMemorySessionService
from google.adk.runners import Runner
from google.adk.tools.tool_context import ToolContext
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %% [markdown]
# ### 1.4: Helper functions
#
# Helper function that manages a complete conversation session, handling session
# creation/retrieval, query processing, and response streaming. It supports
# both single queries and multiple queries in sequence.
#
# Example:
#
# ```
# >>> await run_session(runner, "What is the capital of France?", "geography-session")
# >>> await run_session(runner, ["Hello!", "What's my name?"], "user-intro-session")
# ```

# %%
# Define helper functions that will be reused throughout the notebook
async def run_session(
    runner_instance: Runner,
    user_queries: list[str] | str = None,
    session_name: str = "default",
):
    print(f"\n ### Session: {session_name}")

    # Get app name from the Runner
    app_name = runner_instance.app_name

    # Attempt to create a new session or retrieve an existing one
    try:
        session = await session_service.create_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )
    except:
        session = await session_service.get_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )

    # Process queries if provided
    if user_queries:
        # Convert single query to list for uniform processing
        if type(user_queries) == str:
            user_queries = [user_queries]

        # Process each query in the list sequentially
        for query in user_queries:
            print(f"\nUser > {query}")

            # Convert the query string to the ADK Content format
            query = types.Content(role="user", parts=[types.Part(text=query)])

            # Stream the agent's response asynchronously
            async for event in runner_instance.run_async(
                user_id=USER_ID, session_id=session.id, new_message=query
            ):
                # Check if the event contains valid content
                if event.content and event.content.parts:
                    # Filter out empty or "None" responses before printing
                    if (
                        event.content.parts[0].text != "None"
                        and event.content.parts[0].text
                    ):
                        print(f"{MODEL_NAME} > ", event.content.parts[0].text)
    else:
        print("No queries!")


print("✅ Helper functions defined.")
# Out:
# ✅ Helper functions defined.

# %% [markdown]
# ### 1.5: Configure Retry Options
#
# When working with LLMs, you may encounter transient errors like rate limits or temporary service unavailability. Retry options automatically handle these failures by retrying the request with exponential backoff.

# %%
retry_config = types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],  # Retry on these HTTP errors
)

# %% [markdown]
# ---
# ## 🤹 Section 2: Session Management
#
# ### 2.1 The Problem
#
# At their core, Large Language Models are **inherently stateless**. Their awareness is confined to the information you provide in a single API call. This means an agent without proper context management will react to the current prompt without considering any previous history.
#
# **❓ Why does this matter?** Imagine trying to have a meaningful conversation with someone who forgets everything you've said after each sentence. That's the challenge we face with raw LLMs!
#
# In ADK, we use `Sessions` for **short term memory management** and `Memory` for **long term memory.** In the next notebook, you'll focus on `Memory`.

# %% [markdown]
# ### 2.2 What is a Session?
#
# #### **📦 Session**
#
# A session is a container for conversations. It encapsulates the conversation history in a chronological manner and also records all tool interactions and responses for a **single, continuous conversation**. A session is tied to a user and agent; it is not shared with other users. Similarly, a session history for an Agent is not shared with other Agents.
#
# In ADK, a **Session** is comprised of two key components `Events` and `State`:
#
# **📝 Session.Events**:
#
# > While a session is a container for conversations, `Events` are the building blocks of a conversation.
# >
# > Example of Events:
# > - *User Input*: A message from the user (text, audio, image, etc.)
# > - *Agent Response*: The agent's reply to the user
# > - *Tool Call*: The agent's decision to use an external tool or API
# > - *Tool Output*: The data returned from a tool call, which the agent uses to continue its reasoning
#
#
# **{} Session.State**:
#
# > `session.state` is the Agent's scratchpad, where it stores and updates dynamic details needed during the conversation. Think of it as a global `{key, value}` pair storage which is available to all subagents and tools.

# %% [markdown]
# <img src="https://storage.googleapis.com/github-repo/kaggle-5days-ai/day3/session-state-and-events.png" width="320" alt="Session state and events">
#
# <!-- ```mermaid
# graph TD
#     subgraph A["Agentic Application"];
#         subgraph U["User"]
#             subgraph S1["Session"]
#                 D1["Session.Events"]
#                 D2["Session.State"]
#             end
#         end
#     end
# ``` -->

# %% [markdown]
# ### 2.3 How to manage sessions?
#
# An agentic application can have multiple users and each user may have multiple sessions with the application.
# To manage these sessions and events, ADK offers a **Session Manager** and **Runner**.
#
# 1. **`SessionService`**: The storage layer
#    - Manages creation, storage, and retrieval of session data
#    - Different implementations for different needs (memory, database, cloud)
#
# 2. **`Runner`**: The orchestration layer
#    - Manages the flow of information between user and agent
#    - Automatically maintains conversation history
#    - Handles the Context Engineering behind the scenes
#
# Think of it like this:
#
# - **Session** = A notebook 📓
# - **Events** = Individual entries in a single page 📝
# - **SessionService** = The filing cabinet storing notebooks 🗄️
# - **Runner** = The assistant managing the conversation 🤖

# %% [markdown]
# ### 2.4 Implementing Our First Stateful Agent
#
# Let's build our first stateful agent, that can remember and have constructive conversations.
#
# ADK offers different types of sessions suitable for different needs. As a start, we'll start with a simple Session Management option (`InMemorySessionService`):

# %%
APP_NAME = "default"  # Application
USER_ID = "default"  # User
SESSION = "default"  # Session

MODEL_NAME = "gemini-2.5-flash-lite"


# Step 1: Create the LLM Agent
root_agent = Agent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="text_chat_bot",
    description="A text chatbot",  # Description of the agent's purpose
)

# Step 2: Set up Session Management
# InMemorySessionService stores conversations in RAM (temporary)
session_service = InMemorySessionService()

# Step 3: Create the Runner
runner = Runner(agent=root_agent, app_name=APP_NAME, session_service=session_service)

print("✅ Stateful agent initialized!")
print(f"   - Application: {APP_NAME}")
print(f"   - User: {USER_ID}")
print(f"   - Using: {session_service.__class__.__name__}")
# Out:
# ✅ Stateful agent initialized!
#    - Application: default
#    - User: default
#    - Using: InMemorySessionService

# %% [markdown]
# ### 2.5 Testing Our Stateful Agent
#
# Now let's see the magic of sessions in action!

# %%
# Run a conversation with two queries in the same session
# Notice: Both queries are part of the SAME session, so context is maintained
await run_session(
    runner,
    [
        "Hi, I am Sam! What is the capital of United States?",
        "Hello! What is my name?",  # This time, the agent should remember!
    ],
    "stateful-agentic-session",
)
# Out:
#  ### Session: stateful-agentic-session
#
# User > Hi, I am Sam! What is the capital of United States?
# gemini-2.5-flash-lite >  Hi Sam! The capital of the United States is Washington, D.C.
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  You told me your name is Sam.

# %% [markdown]
# The agent remembered your name because both queries were part of the same session. The Runner automatically maintained the conversation history.
#
# But there's a catch: `InMemorySessionService` is temporary. **Once the application stops, all conversation history is lost.**

# %% [markdown]
# ### 🛑 (Optional) 2.6 Testing Agent's forgetfulness
#
# > To verify that the agent forgets the conversation, **restart the kernel**. Then, **run ALL the previous cells in this notebook EXCEPT the `run_session` in 2.5.**
# >
# > Now run the cell below. You'll see that the agent doesn't remember anything from the previous conversation.

# %%
# Run this cell after restarting the kernel. All this history will be gone...
await run_session(
    runner,
    ["What did I ask you about earlier?", "And remind me, what's my name?"],
    "stateful-agentic-session",
)  # Note, we are using same session name
# Out:
#  ### Session: stateful-agentic-session
#
# User > What did I ask you about earlier?
# gemini-2.5-flash-lite >  You asked me about the capital of the United States.
#
# User > And remind me, what's my name?
# gemini-2.5-flash-lite >  Your name is Sam.

# %% [markdown]
# ### The Problem
#
# Session information is not persistent (i.e., meaningful conversations are lost). While this is advantageous in testing environments, **in the real world, a user should be able to refer from past and resume conversations.** To achieve this, we must persist information.

# %% [markdown]
# ---
# ## 📈 Section 3: Persistent Sessions with `DatabaseSessionService`
#
# While `InMemorySessionService` is great for prototyping, real-world applications need conversations to survive restarts, crashes, and deployments. Let's level up to persistent storage!
#
# ### 3.1 Choosing the Right SessionService
#
# ADK provides different SessionService implementations for different needs:
#
# | Service | Use Case | Persistence | Best For |
# |---------|----------|-------------|----------|
# | **InMemorySessionService** | Development & Testing | ❌ Lost on restart | Quick prototypes |
# | **DatabaseSessionService** | Self-managed apps | ✅ Survives restarts | Small to medium apps |
# | **Agent Engine Sessions** | Production on GCP | ✅ Fully managed | Enterprise scale |

# %% [markdown]
# ### 3.2 Implementing Persistent Sessions
#
# Let's upgrade to `DatabaseSessionService` using SQLite. This gives us persistence without needing a separate database server for this demo.
#
# Let's create a `chatbot_agent` capable of having a conversation with the user.

# %%
# Step 1: Create the same agent (notice we use LlmAgent this time)
chatbot_agent = LlmAgent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="text_chat_bot",
    description="A text chatbot with persistent memory",
)

# Step 2: Switch to DatabaseSessionService
# SQLite database will be created automatically
db_url = "sqlite:///my_agent_data.db"  # Local SQLite file
session_service = DatabaseSessionService(db_url=db_url)

# Step 3: Create a new runner with persistent storage
runner = Runner(agent=chatbot_agent, app_name=APP_NAME, session_service=session_service)

print("✅ Upgraded to persistent sessions!")
print(f"   - Database: my_agent_data.db")
print(f"   - Sessions will survive restarts!")
# Out:
# ✅ Upgraded to persistent sessions!
#    - Database: my_agent_data.db
#    - Sessions will survive restarts!

# %% [markdown]
# ### 3.3 Test Run 1: Verifying Persistence
#
# In this first test run, start a new conversation with the session ID `test-db-session-01`. First introduce our name as 'Sam' and then ask a question. In the second turn, we will ask the agent for our name.
#
# Since using `DatabaseSessionService`, the agent should remember the name.
#
# After the conversation, inspect the `my_agent_data.db` SQLite database directly to see how the conversation `events` (the user queries and model responses) are stored.

# %%
await run_session(
    runner,
    ["Hi, I am Sam! What is the capital of the United States?", "Hello! What is my name?"],
    "test-db-session-01",
)
# Out:
#  ### Session: test-db-session-01
#
# User > Hi, I am Sam! What is the capital of the United States?
# gemini-2.5-flash-lite >  Hello Sam! The capital of the United States is Washington, D.C.
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  Your name is Sam.

# %% [markdown]
# ### 🛑 (Optional) 3.4 Test Run 2: Resuming a Conversation
#
# > ‼️ Now, let's repeat the test again, but this time, **let's stop the Notebook's kernel and restart it again.**
# >
# > 1. Run all the previous cells in the notebook, **EXCEPT** the previous Section 3.3 (`run_session` cell).
# >
# > 2. Now, run the below cell with the **same session ID** (`test-db-session-01`).
#
# We will ask a new question and then ask for our name again. **Because the session is loaded from the database, the agent should still remember** that  name is 'Sam' from the first test run. This demonstrates the power of persistent sessions.

# %%
await run_session(
    runner,
    ["What is the capital of India?", "Hello! What is my name?"],
    "test-db-session-01",
)
# Out:
#  ### Session: test-db-session-01
#
# User > What is the capital of India?
# gemini-2.5-flash-lite >  The capital of India is New Delhi.
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  Your name is Sam.

# %% [markdown]
# ### 3.5 Let's verify that the session data is isolated
#
# As mentioned earlier, a session is private conversation between an Agent and a User (i.e., two sessions do not share information). Let's run our `run_session` with a different session name `test-db-session-02` to confirm this.

# %%
await run_session(
    runner, ["Hello! What is my name?"], "test-db-session-02"
)  # Note, we are using new session name
# Out:
#  ### Session: test-db-session-02
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  I do not have access to your personal information, including your name. I am a text-based chatbot and do not store any user data.

# %% [markdown]
# ### 3.6 How are the events stored in the Database?
#
# Since we are using a sqlite DB to store information, let's have a quick peek to see how information is stored.

# %%
import sqlite3

def check_data_in_db():
    with sqlite3.connect("my_agent_data.db") as connection:
        cursor = connection.cursor()
        result = cursor.execute(
            "select app_name, session_id, author, content from events"
        )
        print([_[0] for _ in result.description])
        for each in result.fetchall():
            print(each)


check_data_in_db()
# Out:
# ['app_name', 'session_id', 'author', 'content']
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hi, I am Sam! What is the capital of the United States?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Hello Sam! The capital of the United States is Washington, D.C."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Your name is Sam."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "What is the capital of India?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "The capital of India is New Delhi."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Your name is Sam."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "What is the capital of India?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "The capital of India is New Delhi."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Your name is Sam."}], "role": "model"}')
# ('default', 'test-db-session-02', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-02', 'text_chat_bot', '{"parts": [{"text": "I do not have access to your personal information, including your name. I am a text-based chatbot and do not store any user data."}], "role": "model"}')

# %% [markdown]
# ---
# ## ⏳ Section 4: Context Compaction
#
# As you can see, all the events are stored in full in the session Database, and this quickly adds up. For a long, complex task, this list of events can become very large, leading to slower performance and higher costs.
#
# But what if we could automatically summarize the past? Let's use ADK's **Context Compaction** feature to see **how to automatically reduce the context that's stored in the Session.**

# %% [markdown]
# <img src="https://storage.googleapis.com/github-repo/kaggle-5days-ai/day3/context-compaction.png" width="1400" alt="Context compaction">

# %% [markdown]
# ### 4.1 Create an App for the agent
#
# To enable this feature, let's use the same `chatbot_agent` we created in Section 3.2.
#
# The first step is to create an object called `App`. We'll give it a name and pass in our chatbot_agent.
#
# We'll also create a new config to do the Context Compaction. This **`EventsCompactionConfig`** defines two key variables:
#
# - **compaction_interval**: Asks the Runner to compact the history after every `n` conversations
# - **overlap_size**: Defines the number of previous conversations to retain for overlap
#
# We'll then provide this app to the Runner.

# %%
# Re-define our app with Events Compaction enabled
research_app_compacting = App(
    name="research_app_compacting",
    root_agent=chatbot_agent,
    # This is the new part!
    events_compaction_config=EventsCompactionConfig(
        compaction_interval=3,  # Trigger compaction every 3 invocations
        overlap_size=1,  # Keep 1 previous turn for context
    ),
)

db_url = "sqlite:///my_agent_data.db"  # Local SQLite file
session_service = DatabaseSessionService(db_url=db_url)

# Create a new runner for our upgraded app
research_runner_compacting = Runner(
    app=research_app_compacting, session_service=session_service
)


print("✅ Research App upgraded with Events Compaction!")
# Out:
# ✅ Research App upgraded with Events Compaction!
# /tmp/ipykernel_48/3773147741.py:6: UserWarning: [EXPERIMENTAL] EventsCompactionConfig: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   events_compaction_config=EventsCompactionConfig(

# %% [markdown]
# ### 4.2 Running the Demo
#
# Now, let's have a conversation that is long enough to trigger the compaction. When you run the cell below, the output will look like a normal conversation. However, because we configured our `App`, a compaction process will run silently in the background after the 3rd invocation.
#
# In the next step, we'll prove that it happened.

# %%
# Turn 1
await run_session(
    research_runner_compacting,
    "What is the latest news about AI in healthcare?",
    "compaction_demo",
)

# Turn 2
await run_session(
    research_runner_compacting,
    "Are there any new developments in drug discovery?",
    "compaction_demo",
)

# Turn 3 - Compaction should trigger after this turn!
await run_session(
    research_runner_compacting,
    "Tell me more about the second development you found.",
    "compaction_demo",
)

# Turn 4
await run_session(
    research_runner_compacting,
    "Who are the main companies involved in that?",
    "compaction_demo",
)
# Out:
#  ### Session: compaction_demo
#
# User > What is the latest news about AI in healthcare?
# gemini-2.5-flash-lite >  The field of AI in healthcare is evolving at an incredibly rapid pace, making it challenging to pinpoint the absolute "latest" news as it changes daily. However, I can provide you with a summary of the most significant and recent trends and developments that are shaping the industry:
#
# **Key Areas of Advancement and News:**
#
# *   **Drug Discovery and Development:**
#     *   **Accelerated Research:** AI is dramatically speeding up the identification of potential drug candidates, predicting their efficacy, and optimizing clinical trial design. Companies are leveraging AI to analyze vast biological datasets and discover novel therapeutic targets.
#     *   **Personalized Medicine:** AI is crucial for analyzing individual patient data (genomics, lifestyle, medical history) to tailor drug treatments and dosages for maximum effectiveness and minimal side effects.
#     *   **New Drug Approvals:** While still a developing area, we're seeing more drugs entering clinical trials that have been discovered or developed with significant AI assistance.
#
# *   **Medical Imaging and Diagnostics:**
#     *   **Enhanced Accuracy and Speed:** AI algorithms are becoming exceptionally good at analyzing medical images (X-rays, CT scans, MRIs, pathology slides) to detect anomalies, often with greater speed and sometimes even higher accuracy than human radiologists or pathologists. This is particularly true for detecting early signs of cancer, diabetic retinopathy, and other conditions.
#     *   **Reduced Radiologist Workload:** AI tools are being deployed to triage urgent cases, highlight suspicious areas, and automate routine tasks, freeing up radiologists for more complex interpretations.
#     *   **New FDA Approvals:** A steady stream of AI-powered medical imaging devices and software are receiving FDA (and other regulatory body) clearance.
#
# *   **Predictive Analytics and Early Disease Detection:**
#     *   **Identifying At-Risk Patients:** AI models can analyze electronic health records (EHRs) and other data to predict which patients are at higher risk of developing certain diseases (e.g., sepsis, heart failure, readmission) allowing for proactive interventions.
#     *   **Outbreak Prediction:** AI is being used to monitor public health data, social media, and news to predict and track disease outbreaks.
#
# *   **Robotics in Surgery and Patient Care:**
#     *   **Enhanced Surgical Precision:** AI-powered robotic surgery systems are becoming more sophisticated, offering greater dexterity, minimally invasive procedures, and improved patient outcomes.
#     *   **Robotic Assistance:** Robots are being explored for tasks like delivering medications, assisting with patient mobility, and even providing companionship in elder care settings.
#
# *   **AI-Powered Virtual Assistants and Chatbots:**
#     *   **Patient Engagement:** Chatbots are being used for symptom checking, appointment scheduling, answering common health questions, and providing medication reminders, improving patient access and engagement.
#     *   **Clinical Workflow Support:** AI assistants are helping clinicians with tasks like summarizing patient notes, generating reports, and accessing medical information.
#
# *   **Administrative Efficiency:**
#     *   **Streamlining Operations:** AI is being used to automate administrative tasks such as billing, coding, scheduling, and managing insurance claims, reducing costs and freeing up staff time.
#
# **Emerging and Hot Topics:**
#
# *   **Generative AI (like ChatGPT):** The rapid advancements in large language models (LLMs) are creating excitement and concern in healthcare. Potential applications include:
#     *   **Medical Documentation:** Generating draft clinical notes, summaries, and discharge instructions.
#     *   **Medical Education:** Creating realistic case studies and training scenarios.
#     *   **Patient Communication:** Drafting patient-friendly explanations of complex medical conditions.
#     *   **However, there are significant concerns about accuracy, bias, patient privacy, and the need for rigorous validation.**
#
# *   **Ethical Considerations and Regulation:**
#     *   **Bias and Equity:** Ensuring AI algorithms do not perpetuate or exacerbate existing healthcare disparities.
#     *   **Data Privacy and Security:** Protecting sensitive patient information when using AI.
#     *   **Transparency and Explainability:** Understanding how AI makes its decisions (the "black box" problem).
#     *   **Regulatory Frameworks:** Governments and regulatory bodies are actively working to establish guidelines and approval processes for AI in healthcare.
#
# *   **Interoperability:** The challenge of integrating AI tools seamlessly into existing healthcare IT systems remains a significant hurdle.
#
# **Where to Find the Latest News:**
#
# To stay truly up-to-date, I recommend following these types of sources:
#
# *   **Reputable Medical Journals:** JAMA, NEJM, The Lancet, Nature Medicine, etc.
# *   **Healthcare Technology News Outlets:** FierceHealthcare, MedTech Dive, STAT News, HIMSS (Healthcare Information and Management Systems Society) news.
# *   **Major AI Conferences:** NeurIPS, ICML, AAAI (often have healthcare tracks).
# *   **Company Press Releases:** Keep an eye on announcements from leading AI and healthcare technology companies.
# *   **Regulatory Agencies:** FDA (for approvals and guidance).
#
# In summary, AI in healthcare is moving from research and development into practical applications across a wide spectrum, with a strong focus on improving diagnosis, treatment, drug discovery, and patient care. The rise of generative AI adds another exciting, albeit complex, layer to these developments.
#
#  ### Session: compaction_demo
#
# User > Are there any new developments in drug discovery?
# gemini-2.5-flash-lite >  Yes, absolutely! Drug discovery is one of the most dynamic and promising areas for AI in healthcare. Here are some of the key new developments and trends:
#
# **1. Generative AI for Novel Molecule Design:**
#
# *   **De Novo Design:** Instead of screening existing libraries of compounds, generative AI models (like Variational Autoencoders, Generative Adversarial Networks, and increasingly, diffusion models) can now **design entirely new molecules from scratch** that are predicted to have specific therapeutic properties. This is a paradigm shift, moving from searching for needles in haystacks to designing the perfect needle.
# *   **"Dreaming" Up Drugs:** These models learn the underlying rules of molecular chemistry and biology from vast datasets and can then "dream up" novel molecular structures optimized for factors like binding affinity to a target, solubility, metabolic stability, and reduced toxicity.
# *   **Examples:** Companies like Insilico Medicine, Recursion Pharmaceuticals, and Atomwise are at the forefront of using generative AI for this purpose, with some of their AI-discovered drug candidates already progressing into clinical trials.
#
# **2. AI-Accelerated Target Identification:**
#
# *   **Uncovering New Disease Mechanisms:** AI can sift through enormous amounts of omics data (genomics, proteomics, transcriptomics, metabolomics) and electronic health records to identify novel biological targets that play a critical role in disease pathways, even those previously unknown or overlooked by human researchers.
# *   **Systems Biology Approach:** AI helps move beyond single-gene or single-protein approaches to understand complex biological networks and identify intervention points within those networks.
#
# **3. Predictive Modeling for Drug Efficacy and Toxicity:**
#
# *   **In Silico Screening:** AI models can predict how a potential drug candidate will interact with its target and how it might behave in the body (pharmacokinetics and pharmacodynamics) *before* expensive and time-consuming lab experiments or animal testing. This significantly reduces the number of compounds that need to be synthesized and tested physically.
# *   **Reducing Late-Stage Failures:** By better predicting efficacy and potential side effects early on, AI helps to de-risk the drug development process and reduce the high failure rates seen in later clinical trial phases.
#
# **4. Optimizing Clinical Trial Design:**
#
# *   **Patient Stratification:** AI can identify patient subgroups most likely to respond to a particular drug, leading to more focused and efficient clinical trials. This is a key component of personalized medicine.
# *   **Predicting Trial Outcomes:** AI can help forecast the likelihood of success for a clinical trial, informing decisions about resource allocation and trial design.
# *   **Synthetic Control Arms:** In some cases, AI is being explored to help create "virtual" control arms for trials, potentially reducing the need for large placebo groups and speeding up recruitment.
#
# **5. Repurposing Existing Drugs:**
#
# *   **Finding New Uses:** AI can analyze known drugs and their interaction profiles against disease targets to identify existing medications that could be repurposed for new therapeutic indications, offering a faster and cheaper route to new treatments.
#
# **6. Advancements in Data Integration and Machine Learning Techniques:**
#
# *   **Graph Neural Networks (GNNs):** These are particularly powerful for modeling molecular structures and interactions, which are inherently graph-like.
# *   **Reinforcement Learning:** Used to iteratively optimize molecule design based on feedback from predictive models.
# *   **Federated Learning:** Allows AI models to be trained on decentralized data sources (e.g., data from multiple hospitals) without compromising patient privacy.
#
# **Challenges Remain:**
#
# Despite these advances, challenges persist:
#
# *   **Data Quality and Accessibility:** High-quality, curated biological and chemical data is essential for training robust AI models.
# *   **Experimental Validation:** AI predictions still require rigorous experimental validation in the lab and clinic.
# *   **Interpretability:** Understanding *why* an AI model makes a particular prediction can be difficult.
# *   **Regulatory Hurdles:** The regulatory pathway for AI-discovered drugs is still evolving.
#
# **In essence, AI is transforming drug discovery from a process of trial-and-error into a more precise, predictive, and design-driven endeavor.** We are seeing a tangible impact with more AI-discovered compounds entering clinical trials and the potential for faster development of novel therapies for a wide range of diseases.
#
#  ### Session: compaction_demo
#
# User > Tell me more about the second development you found.
# gemini-2.5-flash-lite >  You're asking about the **second development** I mentioned: **AI-Accelerated Target Identification**. This is a crucial step in drug discovery because before you can design or find a drug, you need to know *what* to target.
#
# Here's a deeper dive into what AI is doing in this space:
#
# **The Traditional Challenge of Target Identification:**
#
# For decades, identifying a new drug target involved:
#
# *   **Deep Biological Expertise:** Relying on the knowledge of scientists to hypothesize about disease mechanisms and potential molecular culprits.
# *   **Extensive Literature Review:** Manually sifting through millions of research papers.
# *   **Hypothesis-Driven Experiments:** Designing and conducting numerous complex experiments to test specific ideas.
# *   **Often Slow and Laborious:** This process could take years, and many promising hypotheses might never be fully explored due to resource limitations or unforeseen experimental complexities.
#
# **How AI is Revolutionizing Target Identification:**
#
# AI is changing this by enabling a more data-driven and comprehensive approach:
#
# 1.  **Unprecedented Data Analysis Capabilities:**
#     *   **Omics Data Integration:** AI can analyze massive datasets from genomics (DNA), transcriptomics (RNA), proteomics (proteins), and metabolomics (metabolites) generated from patient samples or model systems. It can identify genes, proteins, or metabolic pathways that are consistently altered in diseased states compared to healthy states.
#     *   **Electronic Health Records (EHRs):** AI can mine EHRs for patterns, identifying patient cohorts with specific disease trajectories or unexpected co-morbidities, which can hint at underlying biological mechanisms and potential targets.
#     *   **Scientific Literature Mining:** Natural Language Processing (NLP) techniques allow AI to rapidly scan, understand, and synthesize information from millions of research papers, identifying connections and hypotheses that might be missed by human review.
#
# 2.  **Pattern Recognition and Hypothesis Generation:**
#     *   **Identifying Biomarkers:** AI can discover novel biomarkers that are indicative of a disease state or a patient's response to treatment. These biomarkers often point to the underlying biological processes that could be targeted.
#     *   **Uncovering Complex Relationships:** Diseases are rarely caused by a single factor. AI can untangle complex, multi-factorial relationships within biological systems, revealing new, previously unappreciated, points of intervention. For example, it might identify how a particular protein's malfunction interacts with a metabolic pathway to drive disease.
#     *   **Network Analysis:** AI can map out intricate biological networks (e.g., protein-protein interaction networks) and identify "bottlenecks" or key nodes within these networks whose modulation could have a significant therapeutic effect.
#
# 3.  **Moving Beyond "Druggable" Targets:**
#     *   Historically, researchers focused on targets that were considered "druggable" – meaning they had known binding sites for existing drug classes. AI can help identify targets that might not have obvious binding sites but are still critical to disease, potentially opening up new therapeutic modalities.
#
# **Examples and Impact:**
#
# *   **Companies like Recursion Pharmaceuticals:** They use AI to analyze vast amounts of cellular imaging data, looking for phenotypic changes induced by genetic perturbations or drug treatments. This allows them to infer the function of genes and proteins and identify novel targets for various diseases.
# *   **BenchSci:** This company uses AI to analyze scientific literature and experimental data to help researchers choose the right reagents (like antibodies) and identify potential targets based on published evidence.
# *   **Identifying Novel Cancer Pathways:** AI can analyze tumor genomic data alongside patient outcomes to pinpoint specific mutations or gene expression patterns that drive cancer growth, suggesting new targets for cancer therapies.
# *   **Understanding Neurodegenerative Diseases:** AI can help researchers sift through complex genetic and environmental factors implicated in diseases like Alzheimer's or Parkinson's to identify key proteins or pathways that are good targets for intervention.
#
# **In essence, AI-accelerated target identification allows us to:**
#
# *   **Explore biological space more broadly.**
# *   **Generate novel hypotheses faster.**
# *   **Focus R&D efforts on the most promising targets.**
# *   **Potentially discover treatments for diseases where targets were previously unknown or intractable.**
#
# This development is foundational, as finding the right target is the critical first step in the long journey of bringing a new medicine to patients.
#
#  ### Session: compaction_demo
#
# User > Who are the main companies involved in that?
# gemini-2.5-flash-lite >  Identifying the "main" companies in AI-driven drug discovery is a bit fluid, as new players emerge and established ones expand their AI capabilities. However, here are some of the key companies and types of organizations that are significantly involved in the **AI-accelerated target identification** aspect, and drug discovery more broadly:
#
# **1. Dedicated AI Drug Discovery Platforms (often leading in target ID):**
#
# These companies were built from the ground up with AI at their core, specifically for drug discovery. They often have proprietary platforms that integrate various data types for target identification.
#
# *   **Recursion Pharmaceuticals:** As mentioned before, they use AI and machine learning to analyze vast biological and chemical datasets, particularly high-content cellular imaging, to map disease biology and identify novel targets.
# *   **Insilico Medicine:** Known for their end-to-end AI platform that spans target discovery, molecule generation, and clinical trial prediction. They have been quite public about their AI-discovered candidates.
# *   **Exscientia:** Focuses on AI-driven drug design and discovery, with a strong emphasis on identifying novel targets and then designing molecules to hit them. They have a number of collaborations with large pharmaceutical companies.
# *   **BenevolentAI:** Uses its AI platform to analyze vast amounts of biomedical information (scientific literature, patents, clinical trial data) to identify novel drug targets and new therapeutic uses for existing drugs.
# *   **Atomwise:** While heavily focused on structure-based drug design and virtual screening, their ability to predict protein-ligand interactions can also inform target identification by understanding the "druggability" of potential targets.
# *   **Schrödinger:** While traditionally a computational chemistry company, they have significantly invested in AI and machine learning to accelerate their modeling and prediction capabilities, which directly aids in target identification and validation.
#
# **2. Big Pharma and Established Biotech Companies (investing heavily in internal AI capabilities and partnerships):**
#
# Major pharmaceutical companies are rapidly integrating AI into their own R&D pipelines, both by building internal teams and by partnering with AI-native companies.
#
# *   **Pfizer, Novartis, AstraZeneca, Merck, GSK, Johnson & Johnson, Roche, Sanofi:** All of these giants have dedicated AI/ML teams and are actively using AI for target identification, validation, and the entire drug discovery pipeline. They often announce partnerships and collaborations with smaller AI biotech firms.
# *   **Biogen, Amgen, Gilead:** Other large biotechs that are also investing heavily in AI for target discovery and drug development.
#
# **3. AI/ML Infrastructure and Tool Providers (enabling the field):**
#
# While not directly discovering drugs themselves, these companies provide the foundational AI technologies and platforms that power drug discovery.
#
# *   **NVIDIA:** Their GPUs and AI platforms are crucial for the computationally intensive tasks involved in AI drug discovery, including analyzing large datasets and running complex simulations. They also have specific initiatives and partnerships in the life sciences.
# *   **Google (Google Cloud, DeepMind):** Google's AI capabilities, particularly DeepMind's work on protein folding (AlphaFold, which, while not directly target ID, has massive implications for understanding protein function and thus potential targets), are highly relevant. Google Cloud also offers AI/ML services for life science companies.
# *   **Microsoft (Azure AI):** Similar to Google, Microsoft offers cloud-based AI and ML services that are utilized by life science companies for data analysis and model building.
#
# **4. Academic Institutions and Research Consortia:**
#
# Many breakthroughs in AI for target identification originate from academic research. Universities and consortia often publish their findings and may spin out new companies or license their technologies.
#
# **Key Trend:**
#
# The trend is increasingly towards **collaboration and hybrid models**. Big Pharma, with its deep biological expertise and clinical trial infrastructure, partners with specialized AI companies that have cutting-edge algorithms and platforms. This allows for faster progress by leveraging the strengths of both.
#
# When looking for news, you'll often see announcements from:
#
# *   **Big Pharma company X partners with AI biotech Y** for target discovery in a specific disease area.
# *   **AI company Z announces promising preclinical results** for a drug candidate it identified using its AI platform.
# *   **Academic researchers publish a new AI method** for identifying disease-associated genes.
#
# The landscape is dynamic, so staying updated involves following these companies and the broader news in the biotech and AI sectors.

# %% [markdown]
# ### 4.3 Verifying Compaction in the Session History
#
# The conversation above looks normal, but the history has been changed behind the scenes.
#
# We can inspect the `events` list from our session. The compaction process **doesn't delete old events; it replaces them with a single, new `Event` that contains the summary.** Let's find it.

# %%
# Get the final session state
final_session = await session_service.get_session(
    app_name=research_runner_compacting.app_name,
    user_id=USER_ID,
    session_id="compaction_demo",
)

print("--- Searching for Compaction Summary Event ---")
found_summary = False
for event in final_session.events:
    # Compaction events have a 'compaction' attribute
    if event.actions and event.actions.compaction:
        print("\n✅ SUCCESS! Found the Compaction Event:")
        print(f"  Author: {event.author}")
        print(f"\n Compacted information: {event}")
        found_summary = True
        break

if not found_summary:
    print(
        "\n❌ No compaction event found. Try increasing the number of turns in the demo."
    )
# Out:
# --- Searching for Compaction Summary Event ---
#
# ✅ SUCCESS! Found the Compaction Event:
#   Author: user
#
#  Compacted information: model_version=None content=None grounding_metadata=None partial=None turn_complete=None finish_reason=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=None live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None invocation_id='356022c0-28dc-44ec-877c-8f70298d8a08' author='user' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction={'start_timestamp': 1763499340.872884, 'end_timestamp': 1763499349.152989, 'compacted_content': {'parts': [{'function_call': None, 'code_execution_result': None, 'executable_code': None, 'file_data': None, 'function_response': None, 'inline_data': None, 'text': 'The conversation began with a general inquiry about the latest news in AI in healthcare. The AI agent provided a comprehensive overview of key advancements, including drug discovery, medical imaging, predictive analytics, robotics, virtual assistants, and administrative efficiency. It also highlighted emerging trends like generative AI and ethical considerations, along with recommended sources for staying updated.\n\nThe user then specifically asked for more details on new developments in drug discovery. The AI agent detailed advancements such as:\n\n*   **Generative AI for Novel Molecule Design:** AI can now design entirely new molecules from scratch with desired therapeutic properties.\n*   **AI-Accelerated Target Identification:** AI analyzes vast datasets to identify new biological targets crucial for disease pathways.\n*   **Predictive Modeling for Drug Efficacy and Toxicity:** AI predicts drug behavior and potential side effects early in development.\n*   **Optimizing Clinical Trial Design:** AI aids in patient stratification and predicting trial outcomes.\n*   **Repurposing Existing Drugs:** AI identifies new uses for existing medications.\n*   **Advancements in Data Integration and ML Techniques:** New AI techniques like GNNs and federated learning are being utilized.\n\nFinally, the user requested more information on the **second development**: **AI-Accelerated Target Identification**. The AI agent elaborated on how AI revolutionizes this process by:\n\n*   **Analyzing unprecedented amounts of data:** including omics data and EHRs.\n*   **Recognizing patterns and generating hypotheses:** by identifying biomarkers, uncovering complex biological relationships, and mapping network analyses.\n*   **Moving beyond traditionally "druggable" targets.**\n\nThe agent provided examples of companies and applications utilizing this technology and emphasized its foundational importance in drug discovery.\n\n**Key Information and Decisions:**\n\n*   **Broad overview of AI in healthcare provided.**\n*   **Specific focus on drug discovery advancements.**\n*   **Detailed explanation of AI-accelerated target identification.**\n\n**Unresolved Questions or Tasks:**\n\n*   None. The conversation has been informational, with the user progressively asking for more detail on specific topics.', 'thought': None, 'thought_signature': None, 'video_metadata': None}], 'role': 'model'}}, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=set() branch=None id='41aad820-4db5-4865-a0dd-416460aa68e9' timestamp=1763499355.623572

# %% [markdown]
# **Let's recap what you just witnessed:**
#
# 1.  **Silent Operation**: You ran a standard conversation, and from the outside, nothing seemed different.
# 2.  **Background Compaction**: Because you configured the `App` with `EventsCompactionConfig`, the ADK `Runner` automatically monitored the conversation length. Once the threshold was met, it triggered the summarization process in the background.
# 3.  **Verified Result**: By inspecting the session's events, you found the summary that the LLM generated. This summary now replaces the older, more verbose turns in the agent's active context.
#
# **For all future turns in this conversation, the agent will be given this concise summary instead of the full history.** This saves costs, improves performance, and helps the agent stay focused on what's most important.

# %% [markdown]
# ### 4.5 More Context Engineering options in ADK
#
# #### 👉 Custom Compaction
# In this example, we used ADK's default summarizer. For more advanced use cases, you can provide your own by defining a custom `SlidingWindowCompactor` and passing it to the config. This allows you to control the summarization prompt or even use a different, specialized LLM for the task.
#
# #### 👉 Context Caching
# ADK also provides **Context Caching** to help reduce the token size of the static instructions that are fed to the LLM by caching the request data.

# %% [markdown]
# ### The Problem
#
# While we can do Context Compaction and use a database to resume a session, we face new challenges now. In some cases, **we have key information or preferences that we want to share across other sessions.**
#
# In these scenarios, instead of sharing the entire session history, transferring information from a few key variables can improve the session experience. Let's see how to do it!

# %% [markdown]
# ---
# ## 🤝 Section 5: Working with Session State
#
# ### 5.1 Creating custom tools for Session state management
#
# Let's explore how to manually manage session state through custom tools. In this example, we'll identify a **transferable characteristic**, like a user's name and their country, and create tools to capture and save it.
#
# **Why This Example?**
#
# The username is a perfect example of information that:
#
# - Is introduced once but referenced multiple times
# - Should persist throughout a conversation
# - Represents a user-specific characteristic that enhances personalization
#
# Here, for demo purposes, we'll create two tools that can store and retrieve user name and country from the Session State. **Note that all tools have access to the `ToolContext` object.** You don't have to create separate tools for each piece of information you want to share.

# %%
# Define scope levels for state keys (following best practices)
USER_NAME_SCOPE_LEVELS = ("temp", "user", "app")


# This demonstrates how tools can write to session state using tool_context.
# The 'user:' prefix indicates this is user-specific data.
def save_userinfo(
    tool_context: ToolContext, user_name: str, country: str
) -> Dict[str, Any]:
    """
    Tool to record and save user name and country in session state.

    Args:
        user_name: The username to store in session state
        country: The name of the user's country
    """
    # Write to session state using the 'user:' prefix for user data
    tool_context.state["user:name"] = user_name
    tool_context.state["user:country"] = country

    return {"status": "success"}


# This demonstrates how tools can read from session state.
def retrieve_userinfo(tool_context: ToolContext) -> Dict[str, Any]:
    """
    Tool to retrieve user name and country from session state.
    """
    # Read from session state
    user_name = tool_context.state.get("user:name", "Username not found")
    country = tool_context.state.get("user:country", "Country not found")

    return {"status": "success", "user_name": user_name, "country": country}


print("✅ Tools created.")
# Out:
# ✅ Tools created.

# %% [markdown]
# **Key Concepts:**
# - Tools can access `tool_context.state` to read/write session state
# - Use descriptive key prefixes (`user:`, `app:`, `temp:`) for organization
# - State persists across conversation turns within the same session

# %% [markdown]
# ### 5.2 Creating an Agent with Session State Tools
#
# Now let's create a new agent that has access to our session state management tools:

# %%
# Configuration
APP_NAME = "default"
USER_ID = "default"
MODEL_NAME = "gemini-2.5-flash-lite"

# Create an agent with session state tools
root_agent = LlmAgent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="text_chat_bot",
    description="""A text chatbot.
    Tools for managing user context:
    * To record username and country when provided use `save_userinfo` tool.
    * To fetch username and country when required use `retrieve_userinfo` tool.
    """,
    tools=[save_userinfo, retrieve_userinfo],  # Provide the tools to the agent
)

# Set up session service and runner
session_service = InMemorySessionService()
runner = Runner(agent=root_agent, session_service=session_service, app_name="default")

print("✅ Agent with session state tools initialized!")
# Out:
# ✅ Agent with session state tools initialized!

# %% [markdown]
# ### 5.3 Testing Session State in Action
#
# Let's test how the agent uses session state to remember information across conversation turns:

# %%
# Test conversation demonstrating session state
await run_session(
    runner,
    [
        "Hi there, how are you doing today? What is my name?",  # Agent shouldn't know the name yet
        "My name is Sam. I'm from Poland.",  # Provide name - agent should save it
        "What is my name? Which country am I from?",  # Agent should recall from session state
    ],
    "state-demo-session",
)
# Out:
#  ### Session: state-demo-session
#
# User > Hi there, how are you doing today? What is my name?
# gemini-2.5-flash-lite >  Hello! I'm doing great, thanks for asking. I can't tell you your name just yet, as I haven't been told what it is. If you tell me your name and country, I can remember it for you!
#
#
# User > My name is Sam. I'm from Poland.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# gemini-2.5-flash-lite >  Hello Sam from Poland! It's a pleasure to meet you. How can I help you today?
#
#
# User > What is my name? Which country am I from?
# gemini-2.5-flash-lite >  You told me your name is Sam and you are from Poland.

# %% [markdown]
# ### 5.4 Inspecting Session State
#
# Let's directly inspect the session state to see what's stored:

# %%
# Retrieve the session and inspect its state
session = await session_service.get_session(
    app_name=APP_NAME, user_id=USER_ID, session_id="state-demo-session"
)

print("Session State Contents:")
print(session.state)
print("\n🔍 Notice the 'user:name' and 'user:country' keys storing our data!")
# Out:
# Session State Contents:
# {'user:name': 'Sam', 'user:country': 'Poland'}
#
# 🔍 Notice the 'user:name' and 'user:country' keys storing our data!

# %% [markdown]
# ### 5.5 Session State Isolation
#
# As we've already seen, an important characteristic of session state is that it's isolated per session. Let's demonstrate this by starting a new session:

# %%
# Start a completely new session - the agent won't know our name
await run_session(
    runner,
    ["Hi there, how are you doing today? What is my name?"],
    "new-isolated-session",
)

# Expected: The agent won't know the name because this is a different session
# Out:
#  ### Session: new-isolated-session
#
# User > Hi there, how are you doing today? What is my name?
# gemini-2.5-flash-lite >  Hello! I'm doing great. I can't recall your name just yet. Could you please tell me what it is?

# %% [markdown]
# ### 5.6 Cross-Session State Sharing
#
# While sessions are isolated by default, you might notice something interesting. Let's check the state of our new session (`new-isolated-session`):

# %%
# Check the state of the new session
session = await session_service.get_session(
    app_name=APP_NAME, user_id=USER_ID, session_id="new-isolated-session"
)

print("New Session State:")
print(session.state)

# Note: Depending on implementation, you might see shared state here.
# This is where the distinction between session-specific and user-specific state becomes important.
# Out:
# New Session State:
# {'user:name': 'Sam', 'user:country': 'Poland'}

# %% [markdown]
# ---
#
# ## 🧹 Cleanup

# %%
# Clean up any existing database to start fresh (if Notebook is restarted)
import os

if os.path.exists("my_agent_data.db"):
    os.remove("my_agent_data.db")
print("✅ Cleaned up old database files")
# Out:
# ✅ Cleaned up old database files

# %% [markdown]
# ---
# ## 📊 Summary
#
# 🎉 Congratulations! You've learned the fundamentals of building stateful AI agents:
#
# - ✅ **Context Engineering** - You understand how to assemble context for LLMs using Context Compaction
# - ✅ **Sessions & Events** - You can maintain conversation history across multiple turns
# - ✅ **Persistent Storage** - You know how to make conversations survive restarts
# - ✅ **Session State** - You can track structured data during conversations
# - ✅ **Manual State Management** - You've experienced both the power and limitations of manual approaches
# - ✅ **Production Considerations** - You're ready to handle real-world challenges
